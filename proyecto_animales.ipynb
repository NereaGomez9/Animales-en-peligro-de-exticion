# %%
import pandas as pd

# Cargar CSV
df = pd.read_csv('animales_enriquecidos.csv')

# Normalizar columnas
df.columns = df.columns.str.lower().str.replace(' ', '_')

# Ver las primeras filas
df.head(10)
# Out:
#        nombre_cientifico                nombre_comun          grupo  \
# 0    Myiopsitta monachus           Cotorra argentina           aves
# 1  Acrothamnion preissii                 Desconocido          algas
# 2       Aedes albopictus                 Desconocido  invertebrados
# 3      Alburnus alburnus                     Alburno          peces
# 4      Amandava amandava                Bengalí rojo           aves
# 5         Ameiurus melas              Pez gato negro          peces
# 6      Ammotragus lervia                       Arrui      mamíferos
# 7  Armadillidium vulgare                 Desconocido  invertebrados
# 8  Australoheros facetus                   Chanchito          peces
# 9      Branta canadensis  Barnacla canadiense grande           aves
#
#                      habitat pais categoria_amenaza estado_conservacion  \
# 0  Terrestre (incl. fluvial)   ES       No evaluado                 NaN
# 1                     Marino   ES       No evaluado                 NaN
# ...

# %%
# Lista de grupos que NO son animales
no_animales = ['planta','plantas vasculares','hongos','briofitos','flora','algas','cromistas y bacterias']

# Filtrar solo animales
df_animales = df[~df['grupo'].str.lower().isin(no_animales)]

# Quitar filas sin nombre científico
df_animales = df_animales.dropna(subset=['nombre_cientifico'])

# Ver las primeras filas filtradas
df_animales.head(10)
# Out:
#              nombre_cientifico                nombre_comun          grupo  \
# 0          Myiopsitta monachus           Cotorra argentina           aves
# 2             Aedes albopictus                 Desconocido  invertebrados
# 3            Alburnus alburnus                     Alburno          peces
# 4            Amandava amandava                Bengalí rojo           aves
# 5               Ameiurus melas              Pez gato negro          peces
# 6            Ammotragus lervia                       Arrui      mamíferos
# 7        Armadillidium vulgare                 Desconocido  invertebrados
# 8        Australoheros facetus                   Chanchito          peces
# 9            Branta canadensis  Barnacla canadiense grande           aves
# 10  Bursaphelenchus xylophilus                 Desconocido  invertebrados
#
#                       habitat pais categoria_amenaza estado_conservacion  \
# 0   Terrestre (incl. fluvial)   ES       No evaluado                 NaN
# ...

# %%
# Eliminar invertebrados
df_animales = df_animales[df_animales['grupo'].str.lower() != 'invertebrados']

# Ver resultado
df_animales['grupo'].value_counts()
# Out:
# grupo
# plantas no vasculares    1319
# peces                    1183
# aves                     1107
# ascidios                  270
# mamíferos                 172
# no especificado           108
# reptiles                  107
# anfibios                   39
# Name: count, dtype: int64

# %%
df_animales
# Out:
#          nombre_cientifico       nombre_comun            grupo  \
# 0      Myiopsitta monachus  Cotorra argentina             aves
# 3        Alburnus alburnus            Alburno            peces
# 4        Amandava amandava       Bengalí rojo             aves
# 5           Ameiurus melas     Pez gato negro            peces
# 6        Ammotragus lervia              Arrui        mamíferos
# ...                    ...                ...              ...
# 51469         Rana iberica        Desconocido  no especificado
# 51470         Salmo trutta        Desconocido  no especificado
# 51471        Ciconia nigra        Desconocido  no especificado
# 51472       Vipera seoanei        Desconocido  no especificado
# 51473     Emys orbicularis        Desconocido  no especificado
#
#                          habitat pais categoria_amenaza estado_conservacion  \
# 0      Terrestre (incl. fluvial)   ES       No evaluado                 NaN
# ...

# %%
# Número total de filas
total_filas = len(df_animales)

# Número de nombres científicos únicos
total_unicos = df_animales['nombre_cientifico'].nunique()

print(f"Total de filas: {total_filas}")
print(f"Nombres científicos únicos: {total_unicos}")

# Si hay duplicados
if total_filas > total_unicos:
    print(f"Hay {total_filas - total_unicos} filas duplicadas por nombre científico.")
else:
    print("No hay duplicados en la columna 'nombre_cientifico'.")
# Out:
# Total de filas: 4305
# Nombres científicos únicos: 3672
# Hay 633 filas duplicadas por nombre científico.

# %%
# Mantener solo la primera aparición de cada nombre científico
df_animales = df_animales.drop_duplicates(subset=['nombre_cientifico'], keep='first')

print(f"Filas después de eliminar duplicados: {len(df_animales)}")
# Out:
# Filas después de eliminar duplicados: 3672

# %%
print(df.columns.tolist())
# Out:
# ['nombre_cientifico', 'nombre_comun', 'grupo', 'habitat', 'pais', 'categoria_amenaza', 'estado_conservacion', 'causa_amenaza', 'tipo_habitat', 'area_protegida', 'grupo_extra', 'dieta']

# %%
df_animales = df_animales.drop(columns={'grupo_extra','dieta', 'area_protegida'})

# %%
df_animales
# Out:
#               nombre_cientifico        nombre_comun            grupo  \
# 0           Myiopsitta monachus   Cotorra argentina             aves
# 3             Alburnus alburnus             Alburno            peces
# 4             Amandava amandava        Bengalí rojo             aves
# 5                Ameiurus melas      Pez gato negro            peces
# 6             Ammotragus lervia               Arrui        mamíferos
# ...                         ...                 ...              ...
# 51461  Thamnobryum rudolphianum         Desconocido  no especificado
# 51462          Graphania granti          Owlet moth  no especificado
# 51463      Fissidens nobreganus         Desconocido  no especificado
# 51464     Mesiotelus maderianus         Desconocido  no especificado
# 51465         Trechus picoensis  Cave ground-beetle  no especificado
#
#                          habitat pais categoria_amenaza estado_conservacion  \
# ...

# %%
# Guardar DataFrame en Excel
df_animales.to_excel("animales_filtrados.xlsx", index=False)
print("Archivo Excel creado: 'animales_filtrados.xlsx'")
# Out:
# Archivo Excel creado: 'animales_filtrados.xlsx'
